# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv('D600 Task 3 Dataset 1 Housing Information.csv')

df.head(10)
df.sort_values('Price', ascending=False)
# Out:
#         ID         Price  SquareFootage  NumBathrooms  NumBedrooms  \
# 4436  1879  1.046676e+06        2031.17      4.016232            5
# 6242  5477  1.045707e+06        2526.53      5.208140            4
# 3951   882  1.024519e+06        1875.44      3.663732            5
# 6950  6914  1.021383e+06        2129.83      2.629746            5
# 6947  6909  1.004324e+06        1758.77      4.904512            4
# ...    ...           ...            ...           ...          ...
# 1717  5710  8.759270e+04         550.00      1.504302            3
# 2086  4238  8.755343e+04         921.39      1.000000            2
# 447   3201  8.625022e+04         550.00      1.441651            4
# 1116  1568  8.623883e+04         550.00      1.000000            2
# 653   3653  8.500000e+04        1161.07      1.274588            1
#
#       BackyardSpace  CrimeRate  SchoolRating  AgeOfHome  DistanceToCityCenter  \
# 4436         351.68      17.64         10.00      59.23                 19.47
# 6242         700.53      52.71         10.00       5.82                  2.18
# 3951         663.72      15.84          9.85      72.20                  0.48
# 6950         700.12      36.77         10.00       0.83                 20.87
# 6947         808.22      51.13          7.05      39.84                  5.43
# ...             ...        ...           ...        ...                   ...
# 1717         403.16       7.11          9.03       9.24                 45.87
# 2086         140.16      49.43          5.61      70.67                 39.13
# 447          254.62      18.87          5.93      13.64                 11.44
# 1116          65.14      37.18          4.32      46.18                 13.68
# 653          534.56      19.26          5.71      50.38                 20.06
#
#       ...  RenovationQuality  LocalAmenities  TransportAccess  Fireplace  \
# 4436  ...               9.63            4.75             4.95         No
# 6242  ...               9.40            8.39             9.23        Yes
# 3951  ...               8.18            5.34             7.98         No
# 6950  ...               8.97            8.32            10.00         No
# 6947  ...               6.78            6.66             6.57         No
# ...   ...                ...             ...              ...        ...
# 1717  ...               5.50            3.55             7.99         No
# 2086  ...               4.28           10.00             8.26         No
# 447   ...               2.45           10.00             7.33        Yes
# 1116  ...               1.95            6.22             7.92        Yes
# 653   ...               5.52            9.45             4.27         No
#
#       HouseColor Garage Floors Windows  PreviousSalePrice  IsLuxury
# 4436        Blue    Yes      1       7       7.520478e+05         1
# 6242       Green    Yes      1      14       8.370710e+05         1
# 3951        Blue     No      1      14       8.292074e+05         0
# 6950        Blue     No      1      12       1.013853e+06         1
# 6947       White     No      1       3       7.423944e+05         1
# ...          ...    ...    ...     ...                ...       ...
# 1717       White     No      1      17       5.882918e+03         0
# 2086        Blue    Yes      1       8      -7.039291e+03         1
# 447       Yellow     No      2      33       1.058912e+04         1
# 1116       White     No      1      12       3.265229e+03         0
# 653       Yellow     No      1      19       7.959542e+03         0
#
# [7000 rows x 22 columns]

# %%
sns.barplot(x="SquareFootage",y="Price",data=df)
# Out:
# <Axes: xlabel='SquareFootage', ylabel='Price'>

# %%
iris = sns.load_dataset("iris")
df = pd.DataFrame(iris)
df.describe()
df.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
import numpy as np
a = np.array([1,2,3])
print(a)

b = np.array([(1,2,3),(4,5,6)], dtype = float)
print(b)

c = np.array([[(1,2,3), (4,5,6)], [(3,2,1), (4,5,6)]], dtype = float)
print(c)
# Out:
# [1 2 3]
# [[1. 2. 3.]
#  [4. 5. 6.]]
# [[[1. 2. 3.]
#   [4. 5. 6.]]
#
#  [[3. 2. 1.]
#   [4. 5. 6.]]]

# %%
exponent = np.exp(b)
print(exponent)
# Out:
# [[  2.71828183   7.3890561   20.08553692]
#  [ 54.59815003 148.4131591  403.42879349]]

# %%
def factorial(n):
    if n==0:
        return 1
    else:
        return n * factorial(n -1)
    
results = factorial(5)
print(results)
# Out:
# 120
